# %%
# names of hurricanes
names = ['Cuba I', 'San Felipe II Okeechobee', 'Bahamas', 'Cuba II', 'CubaBrownsville', 'Tampico', 'Labor Day', 'New England', 'Carol', 'Janet', 'Carla', 'Hattie', 'Beulah', 'Camille', 'Edith', 'Anita', 'David', 'Allen', 'Gilbert', 'Hugo', 'Andrew', 'Mitch', 'Isabel', 'Ivan', 'Emily', 'Katrina', 'Rita', 'Wilma', 'Dean', 'Felix', 'Matthew', 'Irma', 'Maria', 'Michael']

# months of hurricanes
months = ['October', 'September', 'September', 'November', 'August', 'September', 'September', 'September', 'September', 'September', 'September', 'October', 'September', 'August', 'September', 'September', 'August', 'August', 'September', 'September', 'August', 'October', 'September', 'September', 'July', 'August', 'September', 'October', 'August', 'September', 'October', 'September', 'September', 'October']

# years of hurricanes
years = [1924, 1928, 1932, 1932, 1933, 1933, 1935, 1938, 1953, 1955, 1961, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2005, 2005, 2005, 2007, 2007, 2016, 2017, 2017, 2018]

# maximum sustained winds (mph) of hurricanes
max_sustained_winds = [165, 160, 160, 175, 160, 160, 185, 160, 160, 175, 175, 160, 160, 175, 160, 175, 175, 190, 185, 160, 175, 180, 165, 165, 160, 175, 180, 185, 175, 175, 165, 180, 175, 160]

# areas affected by each hurricane
areas_affected = [['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], ['The Bahamas', 'Northeastern United States'], ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], ['Jamaica', 'Yucatn Peninsula'], ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], ['Bermuda', 'New England', 'Atlantic Canada'], ['Lesser Antilles', 'Central America'], ['Texas', 'Louisiana', 'Midwestern United States'], ['Central America'], ['The Caribbean', 'Mexico', 'Texas'], ['Cuba', 'United States Gulf Coast'], ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], ['Mexico'], ['The Caribbean', 'United States East coast'], ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], ['The Caribbean', 'United States East Coast'], ['The Bahamas', 'Florida', 'United States Gulf Coast'], ['Central America', 'Yucatn Peninsula', 'South Florida'], ['Greater Antilles', 'Bahamas', 'Eastern United States', 'Ontario'], ['The Caribbean', 'Venezuela', 'United States Gulf Coast'], ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'], ['Bahamas', 'United States Gulf Coast'], ['Cuba', 'United States Gulf Coast'], ['Greater Antilles', 'Central America', 'Florida'], ['The Caribbean', 'Central America'], ['Nicaragua', 'Honduras'], ['Antilles', 'Venezuela', 'Colombia', 'United States East Coast', 'Atlantic Canada'], ['Cape Verde', 'The Caribbean', 'British Virgin Islands', 'U.S. Virgin Islands', 'Cuba', 'Florida'], ['Lesser Antilles', 'Virgin Islands', 'Puerto Rico', 'Dominican Republic', 'Turks and Caicos Islands'], ['Central America', 'United States Gulf Coast (especially Florida Panhandle)']]

# damages (USD($)) of hurricanes
damages = ['Damages not recorded', '100M', 'Damages not recorded', '40M', '27.9M', '5M', 'Damages not recorded', '306M', '2M', '65.8M', '326M', '60.3M', '208M', '1.42B', '25.4M', 'Damages not recorded', '1.54B', '1.24B', '7.1B', '10B', '26.5B', '6.2B', '5.37B', '23.3B', '1.01B', '125B', '12B', '29.4B', '1.76B', '720M', '15.1B', '64.8B', '91.6B', '25.1B']

# deaths for each hurricane
deaths = [90,4000,16,3103,179,184,408,682,5,1023,43,319,688,259,37,11,2068,269,318,107,65,19325,51,124,17,1836,125,87,45,133,603,138,3057,74]

# write your update damages function here:

updated_damages = []
def update_damages(damages):
  for i in damages:
    if i == 'Damages not recorded':
      updated_damages.append(i)
    elif i.find('M') > 0:
      sm = i.strip('M')
      m = float(sm) * 1000000.0
      updated_damages.append(m)
    elif i.find('B') > 0:
      sb = i.strip('B')
      b = float(sb) * 1000000000.0
      updated_damages.append(b)

update_damages(damages)
damages = updated_damages
#print(updated_damages)

# write your construct hurricane dictionary function here:
hurridict = {}
def make_hurridict(names, months,years,max_sustained_winds,areas_affected,damages,deaths):
  for i in range(34):
    mymswaadmgdth = {}
    mymswaadmgdth["Name"] = names[i]
    mymswaadmgdth["Month"] = months[i]
    mymswaadmgdth["Year"] = years[i]
    mymswaadmgdth["Max Sustained Wind"] = max_sustained_winds[i]
    mymswaadmgdth["Areas Affected"] = areas_affected[i]
    mymswaadmgdth["Damage"] = damages[i]
    mymswaadmgdth["Deaths"] = deaths[i]
    a = names[i]
    hurridict[a] = mymswaadmgdth

make_hurridict(names, months,years,max_sustained_winds,areas_affected,damages,deaths)

#print(hurridict)

# write your construct hurricane by year dictionary function here:

hurridict_year = {}
def make_Yhurridict(hurridict):
  for x in hurridict.values():
    current_year = x.get("Year")
    current_cane = x
    #y = {current_year:current_cane}
    if current_year in hurridict_year.keys():
      e = current_cane
      d = hurridict_year[current_year]
      hurridict_year[current_year] = e, d
    else:
      hurridict_year[current_year] = current_cane

make_Yhurridict(hurridict)
#print(hurridict_year)
#for i in hurridict_year.items():
  #print(i)

# write your count affected areas function here:
"""
def affected_count(areas_affected):
  affected_areas = {}
  new_area = []
  for x in areas_affected:
    new_area += x
  sorted_area = sorted(new_area)
  #print(sorted_area)
  for x in sorted_area:
    affected_tally = sorted_area.count(x)
    affected_areas[x] = affected_tally
  print(affected_areas)
affected_count(areas_affected)
"""

affected_areas = {}
new_area = []
for x in areas_affected:
  new_area += x
sorted_area = sorted(new_area)
#print(sorted_area)
for x in sorted_area:
  affected_tally = sorted_area.count(x)
  affected_areas[x] = affected_tally
#print(affected_areas)

# write your find most affected area function here:
def worst(affected_areas):
  worst_num_so_far = 0
  worst_place_so_far = ""
  for i in affected_areas.items():
    if i[1] > worst_num_so_far:
      worst_num_so_far = i[1]
      worst_place_so_far = i[0]
  worst = {worst_place_so_far:worst_num_so_far}
  print(worst)
    
#worst(affected_areas)

# write your greatest number of deaths function here:

def deadliest(deaths,names):
  worst_death_so_far = 0
  worst_dplace_so_far = ""
  for i in range(34):
    if deaths[i] > worst_death_so_far:
      worst_death_so_far = deaths[i]
      worst_dplace_so_far = names[i]
  worst_death = {worst_dplace_so_far:worst_death_so_far}
  print(worst_death)

#deadliest(deaths,names)

# write your catgeorize by mortality function here:

mort_list = []
for x in deaths:
  if x == 0:
    mort_list.append(0)
  elif x > 0 and x <= 100:
    mort_list.append(1)
  elif x > 100 and x <= 500:
    mort_list.append(2)
  elif x > 500 and x <= 1000:
    mort_list.append(3)
  elif x > 1000 and x <= 10000:
    mort_list.append(4)
#print(mort_list)
#print(mort_list[0])

scale0 = []
scale1 = []
scale2 = []
scale3 = []
scale4 = []
for i in range(33):
  if mort_list[i] == 0:
    scale0.append(names[i])
  elif mort_list[i] == 1:
    scale1.append(names[i])
  elif mort_list[i] == 2:
    scale2.append(names[i])
  elif mort_list[i] == 3:
    scale3.append(names[i])
  elif mort_list[i] == 4:
    scale4.append(names[i])
#print(scale0,scale1,scale2,scale3,scale4)

def mort_scale(scale0,scale1,scale2,scale3,scale4):
  mort = {0:scale0,1:scale1,2:scale2,3:scale3,4:scale4}
  print(mort)

#mort_scale(scale0,scale1,scale2,scale3,scale4)

# write your greatest damage function here:
def wreckt(names,hurridict):
  wreckt_dmg = 0
  wreckt_cane = ""
  for i in range(34):
    a = names[i]
    b = hurridict.get(a)
    c = b.get('Damage')
    if c =="Damages not recorded":
      continue
    elif int(c) > wreckt_dmg:
      wreckt_dmg = c
      wreckt_cane = a
  print(wreckt_cane,wreckt_dmg)

#wreckt(names,hurridict)

# write your catgeorize by damage function here:

dmg_list = []
for y in damages:
  if y == "Damages not recorded":
    dmg_list.append(0)
  elif y == 0:
    dmg_list.append(0)
  elif y > 0 and y <= 100000000:
    dmg_list.append(1)
  elif y > 100000000 and y <= 1000000000:
    dmg_list.append(2)
  elif y > 1000000000 and y <= 10000000000:
    dmg_list.append(3)
  elif y > 10000000000 and y <= 50000000000:
    dmg_list.append(4)
  elif y > 50000000000:
    dmg_list.append(5)
#print(dmg_list)
#print(names)
dscale0 = []
dscale1 = []
dscale2 = []
dscale3 = []
dscale4 = []
dscale5 = []
for i in range(34):
  if dmg_list[i] == 0:
    dscale0.append(names[i])
  elif dmg_list[i] == 1:
    dscale1.append(names[i])
  elif dmg_list[i] == 2:
    dscale2.append(names[i])
  elif dmg_list[i] == 3:
    dscale3.append(names[i])
  elif dmg_list[i] == 4:
    dscale4.append(names[i])
  elif dmg_list[i] == 5:
    dscale5.append(names[i])
#print(dscale0,dscale1,dscale2,dscale3,dscale4,dscale5)
def dmg_scale(dscale0,dscale1,dscale2,dscale3,dscale4,dscale5):
  dmg = {0:dscale0,1:dscale1,2:dscale2,3:dscale3,4:dscale4,5:dscale5}
  print(dmg)

dmg_scale(dscale0,dscale1,dscale2,dscale3,dscale4,dscale5)
